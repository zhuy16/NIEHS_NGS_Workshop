# %%
ls | grep STAT1_6h_IFNa_homer
# Out:
# STAT1_6h_IFNa_homer

# %%
du -sh STAT1_6h_IFNa_homer
# Out:
# 6.0M	STAT1_6h_IFNa_homer

# %%
tar -zcvf STAT1_6h_IFNa_homer.tar.gz STAT1_6h_IFNa_homer/
# Out:
# STAT1_6h_IFNa_homer/
# STAT1_6h_IFNa_homer/homerMotifs.motifs10
# STAT1_6h_IFNa_homer/knownResults.html
# STAT1_6h_IFNa_homer/homerResults.html
# STAT1_6h_IFNa_homer/homerMotifs.motifs12
# STAT1_6h_IFNa_homer/homerResults/
# STAT1_6h_IFNa_homer/homerResults/motif10.motif
# STAT1_6h_IFNa_homer/homerResults/motif23.logo.svg
# STAT1_6h_IFNa_homer/homerResults/motif1.similar25.motif
# STAT1_6h_IFNa_homer/homerResults/motif4RV.logo.svg
# STAT1_6h_IFNa_homer/homerResults/motif8RV.logo.svg
# STAT1_6h_IFNa_homer/homerResults/motif2.similar1.motif
# STAT1_6h_IFNa_homer/homerResults/motif22.similar.html
# STAT1_6h_IFNa_homer/homerResults/motif1.similar26.motif
# STAT1_6h_IFNa_homer/homerResults/motif3.info.html
# STAT1_6h_IFNa_homer/homerResults/motif3RV.motif
# STAT1_6h_IFNa_homer/homerResults/motif9.info.html
# STAT1_6h_IFNa_homer/homerResults/motif25.logo.svg
# STAT1_6h_IFNa_homer/homerResults/motif26RV.motif
# STAT1_6h_IFNa_homer/homerResults/motif1.similar21.motif
# ...

# %%
pwd
# Out:
# /spin1/users/classes/NIEHS_NGS/RNA-workshop-2021/chip-seq

# %%
# from your local computer, initiate a terminal and scp transfer the folder to local computer
# scp zhuy16@helix.nih.gov:/spin1/users/classes/NIEHS_NGS/RNA-workshop-2021/chip-seq/STAT1_6h_IFNa_homer.tar.gz .

# %%
# go to http://bejerano.stanford.edu/great/public/html/
